# %% [markdown]
# # Эксперимент CNN для классификации транспорта
#
# Ноутбук предназначен для интерактивных экспериментов. Основной воспроизводимый код находится в папке `src/`.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT / 'src'))

from config import RAW_DATA_DIR
from utils import find_dataset_root, get_image_counts

dataset_root = find_dataset_root(RAW_DATA_DIR)
get_image_counts(dataset_root)
